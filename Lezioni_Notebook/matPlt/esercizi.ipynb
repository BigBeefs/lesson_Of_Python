# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-5,5,100)
y = 2*x+1
plt.plot(x, y, '-r', label='y=2x+1')
plt.title('Graph of y=2x+1')
plt.xlabel('x', color='#1C2843' )
plt.ylabel('y', color='#1C2843')
plt.legend(loc='upper left')  #La legenda fa riferimento all'aggettivo "label" nel plot
#plt.grid()
#plt.show()

# %%
x = np.linspace(-5,5,100)

y = x**3 

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none') #Nasconde la barra destra
ax.spines['top'].set_color('none')  #Nasconde la barra di sopra
ax.xaxis.set_ticks_position('bottom') #Mette le etichette nel punto desiderato
ax.yaxis.set_ticks_position('left')
# plot the function
plt.plot(x,y, '-g')

# %%
x = np.linspace(-np.pi,np.pi,100)
y = np.sin(x)

fig = plt.figure(figsize=(14,8))

ax = fig.add_subplot(3, 4, 1)#(righe,colonne,posizione della tabella) 
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
plt.xlabel('1', color='g')
plt.plot(x,y, 'b')

z = np.cos(x)
ax = fig.add_subplot(3, 4, 2)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
plt.xlabel('2', color='g')
plt.plot(x,z, 'r')

k = np.exp(x)
ax = fig.add_subplot(3, 4, 3)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
plt.xlabel('3', color='g')
plt.plot(x,k, 'm')

i = np.power(x,3)
ax = fig.add_subplot(3, 4, 4)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
plt.xlabel('4', color='g')
plt.plot(x,i, 'g')

ax = fig.add_subplot(3, 4, 9)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
plt.xlabel('9', color='g')
plt.plot(x,i, 'g')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-np.pi,np.pi,100)
y = np.sin(x)
z = np.cos(x)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

plt.plot(x,y, 'c', label='y=sin(x)')
plt.plot(x,z, 'm', label='z=cos(x)')
plt.legend(loc='upper left')

# %%
x = np.linspace(-2,2,100)
y = np.exp(x)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

plt.plot(x,y, 'y', label='y=e^x')
plt.legend(loc='upper left')
