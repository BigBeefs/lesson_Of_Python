# %% [markdown]
# # Lesson 23/03, #
# ## Matplotlib 2 | DataFrame in plot  ##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('company_sales_data.csv')
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
import calendar

for month_idx in range(1, 13):  #Con un ciclo for printiamo i mesi dell'anno
    print (calendar.month_name[month_idx])
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
month_word = {      #Creiamo un dizionario con all'interno i nomi dei mesi assocciati ai loro numeri
1:'January',
2:'February',
3:'March',
4:'April',
5:'May',
6:'June',
7:'July',
8:'August',
9:'September',
10:'October',
11:'November',
12:'December'
}

# %%
#Assegnamo il nuovo dizionario alla colonna month_number
df['month_number'] = df['month_number'].map(month_word)
df
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0       January       2500      1500        5200         9200     1200
# 1      February       2630      1200        5100         6100     2100
# 2         March       2140      1340        4550         9550     3550
# 3         April       3400      1130        5870         8870     1870
# 4           May       3600      1740        4560         7760     1560
# 5          June       2760      1555        4890         7490     1890
# 6          July       2980      1120        4780         8980     1780
# 7        August       3700      1400        5860         9960     2860
# 8     September       3540      1780        6100         8100     2100
# 9       October       1990      1890        8300        10300     2300
# 10     November       2340      2100        7300        13300     2400
# 11     December       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
#rinominiamo la colonna del month_number
df.rename(columns={'month_number':'month'}, inplace=True)
df
# Out:
#         month  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0     January       2500      1500        5200         9200     1200
# 1    February       2630      1200        5100         6100     2100
# 2       March       2140      1340        4550         9550     3550
# 3       April       3400      1130        5870         8870     1870
# 4         May       3600      1740        4560         7760     1560
# 5        June       2760      1555        4890         7490     1890
# 6        July       2980      1120        4780         8980     1780
# 7      August       3700      1400        5860         9960     2860
# 8   September       3540      1780        6100         8100     2100
# 9     October       1990      1890        8300        10300     2300
# 10   November       2340      2100        7300        13300     2400
# 11   December       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %% [markdown]
# ## Creiamo un grafico con delle liste ##

# %%
profitList = df ['total_profit'].tolist()
monthList  = df ['month'].tolist()

# %%
profitList
# Out:
# [211000,
#  183300,
#  224700,
#  222700,
#  209600,
#  201400,
#  295500,
#  361400,
#  234000,
#  266700,
#  412800,
#  300200]

# %%
monthList
# Out:
# ['January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August',
#  'September',
#  'October',
#  'November',
#  'December']

# %% [markdown]
# ## Grafico con l'analisi delle vendite comparate ai mesi ##

# %%
plt.figure(figsize=(12,8))
plt.plot(monthList, profitList, label = 'Month-wise Profit data of last year')

#       color='r', marker='o', markerfacecolor='k', 
#       linestyle='--', linewidth=3);

plt.xlabel('Months')
plt.ylabel('Profit in dollar')

plt.xticks(monthList)
plt.legend(loc='upper left')
plt.title('Company profit per month')
plt.yticks([100000, 200000, 300000, 400000, 500000])
#plt.xticks([3, 6, 9, 12]);

#plt.show()
# Out:
# ([<matplotlib.axis.YTick at 0x20fbcbaf940>,
#   <matplotlib.axis.YTick at 0x20fbcbaf2e0>,
#   <matplotlib.axis.YTick at 0x20fab8aab90>,
#   <matplotlib.axis.YTick at 0x20fbcc5f220>,
#   <matplotlib.axis.YTick at 0x20fbcc79870>],
#  [Text(0, 100000, '100000'),
#   Text(0, 200000, '200000'),
#   Text(0, 300000, '300000'),
#   Text(0, 400000, '400000'),
#   Text(0, 500000, '500000')])

# %%
df ['total_profit'].sum() #Facciamo la somma dei valori della colonna
# Out:
# 3123300

# %%
# Con il comando "tolist()" assegnamo i valori delle colonne a una lista e assegnate a un dataFrame
monthList  = df ['month'].tolist() 
faceCremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['facewash'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
bathingsoapSalesData   = df ['bathingsoap'].tolist()
shampooSalesData   = df ['shampoo'].tolist()
moisturizerSalesData = df ['moisturizer'].tolist()


plt.figure(figsize=(16,10))
plt.plot(monthList, faceCremSalesData,   label = 'Face cream Sales Data', marker='o', linewidth=3)
plt.plot(monthList, faceWashSalesData,   label = 'Face Wash Sales Data',  marker='o', linewidth=3)
plt.plot(monthList, toothPasteSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=3)
plt.plot(monthList, bathingsoapSalesData, label = 'Bathingsoap Sales Data', marker='o', linewidth=3)
plt.plot(monthList, shampooSalesData, label = 'Shampoo Sales Data', marker='o', linewidth=3)
plt.plot(monthList, moisturizerSalesData, label = 'Moisturize Sales Data', marker='o', linewidth=3)

plt.xlabel('Months')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.xticks(monthList)
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])
plt.title('Sales data')
# Out:
# Text(0.5, 1.0, 'Sales data')

# %% [markdown]
# ## Creiamo un grazico a torta per vedere le vendite totali ##

# %%
df.columns
# Out:
# Index(['month', 'facecream', 'facewash', 'toothpaste', 'bathingsoap',
#        'shampoo', 'moisturizer', 'total_units', 'total_profit'],
#       dtype='object')

# %%
labels = ['facecream', 'facewash', 'toothpaste', 'bathingsoap',
       'shampoo', 'moisturizer']
salesData   = [df ['facecream'].sum(), df ['facewash'].sum(), df ['toothpaste'].sum(), 
         df ['bathingsoap'].sum(), df ['shampoo'].sum(), df ['moisturizer'].sum()]

# %%
plt.figure(figsize=(12,8))
#plt.axis("equal")

plt.pie(salesData, labels=labels, autopct='%1.1f%%') #con "autopct" calcoliamo in automatico le perc nel grafico
plt.legend(loc='upper right')
plt.title('Sales data')
#plt.show()
# Out:
# Text(0.5, 1.0, 'Sales data')

# %% [markdown]
# ## Stackplot ##

# %%
monthList  = df ['month'].tolist()

faceCremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['facewash'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
bathingsoapSalesData   = df ['bathingsoap'].tolist()
shampooSalesData   = df ['shampoo'].tolist()
moisturizerSalesData = df ['moisturizer'].tolist()


plt.figure(figsize=(12,8))

plt.stackplot(monthList, faceCremSalesData, faceWashSalesData, toothPasteSalesData, 
              bathingsoapSalesData, shampooSalesData, moisturizerSalesData) 
              #colors=['m','c','r','k','g','y'])

plt.xlabel('Month Number')
plt.ylabel('Sales unints in Number')
plt.title('Alll product sales data using stack plot')

#plt.show()
# Out:
# Text(0.5, 1.0, 'Alll product sales data using stack plot')

# %% [markdown]
# ## PLOTTARE DIRETTAMENTE DA DATAFRAME CON PANDAS ##

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
Data = {'Country': ['USA','Canada','Germany','UK','France'],
        'GDP': [45000,42000,52000,49000,47000]}
  
df = pd.DataFrame(Data)

# %%
df
# Out:
#    Country    GDP
# 0      USA  45000
# 1   Canada  42000
# 2  Germany  52000
# 3       UK  49000
# 4   France  47000

# %%
#Con df.plot creiamo direttamente in una riga il plot

df.plot(x ='Country',y='GDP', figsize=(5, 5),kind = 'line')

#plt.show()
# Out:
# <Axes: xlabel='Country'>

# %%
df.plot(x ='Country',y='GDP', figsize=(5, 5),kind = 'bar')
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# ## Piechart from DATAFRAME ##

# %%
Data = {'Tasks': [300,500,700]}
df = pd.DataFrame(Data,columns=['Tasks'])

# %%
df.head()
# Out:
#    Tasks
# 0    300
# 1    500
# 2    700

# %%
#Modifichiamo i nomi delle righe e delle colonne
df = pd.DataFrame(Data,columns=['Tasks'],
                  index = ['Tasks Pend','Tasks hold','Tasks Com'])
df.head()
# Out:
#             Tasks
# Tasks Pend    300
# Tasks hold    500
# Tasks Com     700

# %%
df.plot(y='Tasks',figsize=(10, 10),autopct='%1.0f%%',kind='pie', startangle=90)
#plt.show()
# Out:
# <Axes: ylabel='Tasks'>

# %% [markdown]
# ## Grouby Pandas ##

# %%
import html5lib as html
import lxml as lx
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 import html5lib as html
#       2 import lxml as lx
#
# ModuleNotFoundError: No module named 'html5lib'

# %%
url_superficie = "https://it.wikipedia.org/wiki/Primi_100_comuni_italiani_per_superficie"

# %%
comuni_superficie = pd.read_html(url_superficie,attrs={"class":"wikitable"},header=0)

comuni_superficie = comuni_superficie[0]

type(comuni_superficie)
# Out:
# pandas.core.frame.DataFrame

# %%
comuni_superficie.head()
# Out:
#    Pos.     Comune         Regione Provincia Superficie (km²)
# 0     1       Roma           Lazio      Roma         1 287,36
# 1     2    Ravenna  Emilia-Romagna   Ravenna            65382
# 2     3  Cerignola          Puglia    Foggia            59393
# 3     4       Noto         Sicilia  Siracusa            55499
# 4     5    Sassari        Sardegna   Sassari            54704

# %%
# Scartiamo la prima riga perchè non leggibile da pandas "1 287,36"
comuni_superficie = comuni_superficie[1:]

# %%
#trasformiamo tutto il data det in int64
comuni_superficie['Superficie (km²)'] = comuni_superficie['Superficie (km²)'].astype('Int64')
# Out:
# C:\Users\libero.bo\AppData\Local\Temp\ipykernel_2408\2835303725.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comuni_superficie['Superficie (km²)'] = comuni_superficie['Superficie (km²)'].astype('Int64')

# %%
comuni_superficie.columns
# Out:
# Index(['Pos.', 'Comune', 'Regione', 'Provincia', 'Superficie (km²)'], dtype='object')

# %%
# Aggrega i dati degli elementi della colonna
comuni_superficie.groupby('Regione').mean()
# Out:
# C:\Users\libero.bo\AppData\Local\Temp\ipykernel_2408\2630618129.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   comuni_superficie.groupby('Regione').mean()
#                           Pos.  Superficie (km²)
# Regione
# Abruzzo               9.000000           47391.0
# Basilicata           54.666667           29641.0
# Calabria             52.333333      28937.666667
# Emilia-Romagna       56.200000           31154.1
# Lazio                38.666667      32106.333333
# Liguria              80.000000           24029.0
# Lombardia            94.500000           22701.5
# Marche               84.333333           24168.0
# Puglia               46.210526      33034.263158
# Sardegna             62.625000         29839.375
# Sicilia              46.300000          32300.15
# Toscana              52.142857      29941.357143
# Trentino-Alto Adige  56.000000           27485.0
# Umbria               32.142857      36175.285714
# Veneto               49.000000           30853.0

# %%
#Cerchiamo chi ha più citta con maggiore superficie
comuni_superficie.groupby('Regione')['Superficie (km²)'].count()
# Out:
# Regione
# Abruzzo                 1
# Basilicata              3
# Calabria                3
# Emilia-Romagna         10
# Lazio                   3
# Liguria                 1
# Lombardia               2
# Marche                  3
# Puglia                 19
# Sardegna                8
# Sicilia                20
# Toscana                14
# Trentino-Alto Adige     2
# Umbria                  7
# Veneto                  3
# Name: Superficie (km²), dtype: int64

# %%
comuni_superficie.groupby('Regione')['Superficie (km²)'].count().sort_values(ascending=False)
# Out:
# Regione
# Sicilia                20
# Puglia                 19
# Toscana                14
# Emilia-Romagna         10
# Sardegna                8
# Umbria                  7
# Basilicata              3
# Calabria                3
# Lazio                   3
# Marche                  3
# Veneto                  3
# Lombardia               2
# Trentino-Alto Adige     2
# Abruzzo                 1
# Liguria                 1
# Name: Superficie (km²), dtype: int64

# %% [markdown]
# ## Esercizio PETS ##

# %%
df = pd.DataFrame({
    'name':['john','mary','peter','jeff','bill','lisa','jose'],
    'age':[23,78,22,19,45,33,20],
    'gender':['M','F','M','M','M','F','M'],
    'state':['california','dc','california','dc','california','texas','texas'],
    'num_children':[2,0,0,3,2,1,4],
    'num_pets':[5,1,0,5,2,2,3]
})

#df[['name','age','gender','state','num_children','num_pets']]
df
# Out:
#     name  age gender       state  num_children  num_pets
# 0   john   23      M  california             2         5
# 1   mary   78      F          dc             0         1
# 2  peter   22      M  california             0         0
# 3   jeff   19      M          dc             3         5
# 4   bill   45      M  california             2         2
# 5   lisa   33      F       texas             1         2
# 6   jose   20      M       texas             4         3

# %%
df.columns
# Out:
# Index(['name', 'age', 'gender', 'state', 'num_children', 'num_pets'], dtype='object')

# %%
df.plot(kind='scatter',x='num_children',y='num_pets',color='purple')
# Out:
# <Axes: xlabel='num_children', ylabel='num_pets'>

# %%
df.plot(kind='scatter',x='age',y='num_pets',color='green')
# Out:
# <Axes: xlabel='age', ylabel='num_pets'>

# %%
df.plot(kind='line',x='name',y='num_children')
df.plot(kind='line',x='name',y='num_pets', color='red')
# Out:
# <Axes: xlabel='name'>

# %%
# Con plt.gca() raggrupa in un unico plot entrambe le line
ax = plt.gca()
df.plot(kind='line',x='name',y='num_children',ax=ax)
df.plot(kind='line',x='name',y='num_pets', color='red', ax=ax)
# Out:
# <Axes: xlabel='name'>

# %%
df.groupby(['state','gender']).size().plot(kind='bar')
# Out:
# <Axes: xlabel='state,gender'>

# %%
# Con unstack cambia i colori a i due dati
df.groupby(['state','gender']).size().unstack().plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='state'>
